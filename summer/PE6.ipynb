# %% [markdown]
# Test case sum of squares vs square of sum

# %%
i=0
j=0
for n in range(11):
    i+=n
print i
# Out:
# 55

# %%
i=0
j=0
for n in range(11):
    i+=n
    j+=n**2
    print i**2,j,i**2 -j
# Out:
# 0 0 0
# 1 1 0
# 9 5 4
# 36 14 22
# 100 30 70
# 225 55 170
# 441 91 350
# 784 140 644
# 1296 204 1092
# 2025 285 1740
# 3025 385 2640

# %%
i=0
j=0
for n in range(101):
    i+=n
    j+=n**2
    print i**2,j,i**2 -j
# Out:
# 0 0 0
# 1 1 0
# 9 5 4
# 36 14 22
# 100 30 70
# 225 55 170
# 441 91 350
# 784 140 644
# 1296 204 1092
# 2025 285 1740
# 3025 385 2640
# 4356 506 3850
# 6084 650 5434
# 8281 819 7462
# 11025 1015 10010
# 14400 1240 13160
# 18496 1496 17000
# 23409 1785 21624
# 29241 2109 27132
# 36100 2470 33630
# 44100 2870 41230
# 53361 3311 50050
# 64009 3795 60214
# 76176 4324 71852
# 90000 4900 85100
# 105625 5525 100100
# 123201 6201 117000
# 142884 6930 135954
# 164836 7714 157122
# 189225 8555 180670
# 216225 9455 206770
# 246016 10416 235600
# 278784 11440 267344
# 314721 12529 302192
# 354025 13685 340340
# 396900 14910 381990
# 443556 16206 427350
# 494209 17575 476634
# 549081 19019 530062
# 608400 20540 587860
# 672400 22140 650260
# 741321 23821 717500
# 815409 25585 789824
# 894916 27434 867482
# 980100 29370 950730
# 1071225 31395 1039830
# 1168561 33511 1135050
# 1272384 35720 1236664
# 1382976 38024 1344952
# 1500625 40425 1460200
# 1625625 42925 1582700
# 1758276 45526 1712750
# ...
