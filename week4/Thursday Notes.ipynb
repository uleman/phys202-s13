# %%
from Electrostatics import *

# %% [markdown]
# BOOLEAN mask

# %%
theta=arange(0.,2*pi,pi/100)
plot(theta,sin(theta))

# %%
mask = (sin(theta)>0) & (sin(theta)<0.5)
#print mask
plot(theta,sin(theta),theta[mask],sin(theta[mask]))
# Out:
# [<matplotlib.lines.Line2D at 0x10a61ca50>,
#  <matplotlib.lines.Line2D at 0x10a61cb50>]

# %%
y = sin(theta[mask])
jj=(y==max(y))
y[jj] = NaN

# %%
plot(theta,sin(theta))
plot(theta[mask],y,linewidth=4)
#show() supresses the code line of info (try if you dont understand)

# %% [markdown]
# Interpolation
# -

# %%
theta=arange(0.,2*pi+0.1,pi/10)
mask=(theta==0.5)
print mask
# Out:
# [False False False False False False False False False False False False
#  False False False False False False False False False]

# %%
newtheta=0.5;newsin=0.
from scipy.interpolate import interp1d
sinInterp=interp1d(theta,sin(theta))
#help(interp1d)

# %%
newsin=sinInterp(newtheta)
print newsin
# Out:
# 0.473922198704

# %%
plot(theta,sin(theta),newtheta,newsin,'r+',markersize=100,markeredgewidth=6)
# Out:
# [<matplotlib.lines.Line2D at 0x10a995e50>,
#  <matplotlib.lines.Line2D at 0x10a99a350>]

# %%
thetanew=arange(0,2*pi+0.1,pi/30)
sinnew=interp1d(theta,sin(theta))(thetanew)
plot(thetanew,sinnew,'y.')

# %%
plot(thetanew,sinnew-sin(thetanew))
ylabel('difference between interp and exact value')

# %%
sinnewc=interp1d(theta, sin(theta), kind='cubic')(thetanew)
subplot(2,1,1)
plot(thetanew,sinnew-sin(thetanew),thetanew,sinnewc-sin(thetanew),'o')
subplot(2,1,2)
plot(thetanew,sinnewc-sin(thetanew),'r')
