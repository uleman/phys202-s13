# %% [markdown]
# $\psi_k(x)$ = $A\left(\frac{(ik-a\tanh(ax))}{(ik+a)}\right)e^{+ikx}$

# %% [markdown]
# $v_1= m_2\sqrt{\frac{2G}{M}\left(\frac{1}{r}-\frac{1}{r_0}\right)}$

# %% [markdown]
# $f(\theta)=\frac{\hbar}{p}\displaystyle\sum^\infty_{l=2}(2l+1)e^{i\delta_l}\sin\delta_lP_l(\cos\theta)$

# %% [markdown]
# $\frac{d\sigma}{d\Omega} = \frac{k\pi^2(\pi-\theta)}{mu_0^2\theta^2(2\pi-\theta)^2\sin\theta}$

# %% [markdown]
# $\langle f\rangle= \frac{1}{\tau}\displaystyle\int_0^\tau f(t)dt.$

# %% [markdown]
# $\Omega_S=\omega\frac{\sin\alpha}{\sin\theta}=\frac{L}{\lambda_1}=\omega\frac{\sqrt{\lambda^2_3+(\lambda_1^2-\lambda^2_3)\sin\alpha}}{\lambda_1}$

# %% [markdown]
# Graphics Exercise #2
# -
# Phys 212 plot
# -

# %%
x=arange(-4,4,0.1)
plot(x,-1/cosh(x)**2)
plot(x,(0**2+tanh(x)**2)/(0**2+1)) 
plot(x,(0.5**2+tanh(x)**2)/(0.5**2+1))
plot(x,(1**2+tanh(x)**2)/(1**2+1))
plot(x,(2**2+tanh(x)**2)/(2**2+1))
xticks(
