# %% [markdown]
# 4/16/13 tuesday notes
# -

# %%
t=arange(0.0,1.0+0.01, 0.01)
c=cos(4*pi*t)
s=sin(4*pi*t)

# %%
print pi
# Out:
# 3.14159265359

# %%
import numpy as np

# %%
fig = plot(t,s, label = "$sin(4{\pi}t)$")
plot(t,c, color = "maroon",linewidth = 22,linestyle=':', label = "$cos(4{\pi}t$")
xlabel('time(s)')
ylabel('voltage(mV)')
#not for qlab! add title for convenience
title('A simple plot', fontsize = 40)
grid(True)
legend(loc="best")
savefig('simple plot.pdf')
