# %%
f=lambda x: x**(0.5) +sin(x)

# %%
x=arange(0.,15.,0.001)

# %%
p = plot(x,f(x),lw=3)
ylabel(r'$x^(1/2)+\sin(X)$',fontsize=20)
xlabel(r'$x$', fontsize=20)
xlim(0.,15.)
show()

# %%
xmin=1.7
xmax=12.4
subx=x[logical_and((x>xmin),(x<xmax))]
ymax=max(f(subx))*1.05
ymin=0.
myplot=plot(x,f(x),lw=3)
xlim(0.,15.)
plot([xmin,xmin],[ymin,ymax], color = 'black',linestyle='--')
plot([xmax,xmax],[ymin,ymax], color = 'black',linestyle='--')
plot([xmin,xmax],[ymax,ymax], color = 'black',linestyle='--')

# %%
N=10000
samples_x=xmin+(xmax-xmin)*random_sample(N)
samples_y=ymin+(ymax-ymin)*random_sample(N)
p=plot(x,f(x),lw=3)
xlim(0.,15.)
plot(samples_x[1:200],samples_y[1:200],'.')
plot([xmin,xmin],[ymin,ymax], color = 'black',linestyle='--')
plot([xmax,xmax],[ymin,ymax], color = 'black',linestyle='--')
plot([xmin,xmax],[ymax,ymax], color = 'black',linestyle='--')
show
# Out:
# <function matplotlib.pyplot.show>

# %%
newmask=(samples_y<f(samples_x))
sum(newmask)
# Out:
# 6210

# %%
p=plot(x,f(x),lw=3)
xlim(0.,15.)
plot(samples_x[1:200],samples_y[1:200],'.')
plot(samples_x[newmask[:200]],samples_y[newmask[:200]],'r.')
plot([xmin,xmin],[ymin,ymax], color = 'black',linestyle='--')
plot([xmax,xmax],[ymin,ymax], color = 'black',linestyle='--')
plot([xmin,xmax],[ymax,ymax], color = 'black',linestyle='--')
show
# Out:
# <function matplotlib.pyplot.show>

# %%
I=(xmax-xmin)*(ymax-ymin)*sum(newmask)/newmask.size
print I
# Out:
# 26.6398566486

# %%
Iana=lambda x:(2./3.)*x**(3./2.)-cos(x)
Iexact=Iana(xmax)-Iana(xmin)
Ierr= 100*(Iexact-I)/Iexact
print Iexact
print I
print Ierr
# Out:
# 26.5172145362
# 26.6398566486
# -0.462499981734

# %% [markdown]
# Now for an error less than .001%

# %%
N=10**(7)
samples_x=xmin+(xmax-xmin)*random_sample(N)
samples_y=ymin+(ymax-ymin)*random_sample(N)
p=plot(x,f(x),lw=3)
xlim(0.,15.)
plot(samples_x[1:2000],samples_y[1:2000],'.')

plot([xmin,xmin],[ymin,ymax], color = 'black',linestyle='--')
plot([xmax,xmax],[ymin,ymax], color = 'black',linestyle='--')
plot([xmin,xmax],[ymax,ymax], color = 'black',linestyle='--')
show
# Out:
# <function matplotlib.pyplot.show>

# %%
newmask=(samples_y<f(samples_x))
sum(newmask)
# Out:
# 6181500

# %%
p=plot(x,f(x),lw=3)
xlim(0.,15.)
plot(samples_x[1:200],samples_y[1:200],'.')
plot(samples_x[newmask[:200]],samples_y[newmask[:200]],'r.')
plot([xmin,xmin],[ymin,ymax], color = 'black',linestyle='--')
plot([xmax,xmax],[ymin,ymax], color = 'black',linestyle='--')
plot([xmin,xmax],[ymax,ymax], color = 'black',linestyle='--')
show
# Out:
# <function matplotlib.pyplot.show>

# %%
I=(xmax-xmin)*(ymax-ymin)*sum(newmask)/newmask.size
print I
# Out:
# 26.5175964369

# %%
Iana=lambda x:(2./3.)*x**(3./2.)-cos(x)
Iexact=Iana(xmax)-Iana(xmin)
Ierr= 100*(Iexact-I)/Iexact
print Iexact
print I
print Ierr
# Out:
# 26.5172145362
# 26.5175964369
# -0.00144019920922
